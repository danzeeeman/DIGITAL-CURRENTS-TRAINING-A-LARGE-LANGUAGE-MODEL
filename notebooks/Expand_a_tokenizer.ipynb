# %%
import os
from dataclasses import dataclass, field
from typing import Optional
import pandas as pd
import json

import torch
from datasets import load_dataset
from datasets import load_from_disk
from peft import LoraConfig
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    AutoTokenizer,
    TrainingArguments,
)
from tqdm.notebook import tqdm

from trl import SFTTrainer
from huggingface_hub import interpreter_login

# %%
# This can take a few minutes to load, so grab a coffee or tea while you wait!
raw_datasets = load_dataset("json", data_files="./2011_2023_event_des.json", field='data', split='all')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
raw_datasets['train']
# Out:
# ['Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430895, "name": "maicer izturis"}}}? \n Output: {"result": {"event": "field_out", "des": "Maicer Izturis grounds out, second baseman Chris Getz to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 435062, "name": "howie kendrick"}}}? \n Output: {"result": {"event": "double", "des": "Howie Kendrick doubles (1) on a line drive to left fielder Alex Gordon."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 110029, "name": "bobby abreu"}}}? \n Output: {"result": {"event": "strikeout", "des": "Bobby Abreu called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 116338, "name": "torii hunter"}}}? \n Output: {"result": {"event": "field_error", "des": "Torii Hunter reaches on a fielding error by third baseman Mike Aviles.   Howie Kendrick to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 150484, "name": "vernon wells"}}}? \n Output: {"result": {"event": "hit_by_pitch", "des": "Vernon Wells hit by pitch.    Torii Hunter to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430947, "name": "erick aybar"}}}? \n Output: {"result": {"event": "field_out", "des": "Erick Aybar grounds out, second baseman Chris Getz to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "strikeout", "des": "Mike Aviles called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 466320, "name": "melky cabrera"}}}? \n Output: {"result": {"event": "field_out", "des": "Melky Cabrera pops out softly to shortstop Erick Aybar."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 460086, "name": "alex gordon"}}}? \n Output: {"result": {"event": "field_out", "des": "Alex Gordon pops out to shortstop Erick Aybar."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 444432, "name": "mark trumbo"}}}? \n Output: {"result": {"event": "strikeout", "des": "Mark Trumbo strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 425772, "name": "jeff mathis"}}}? \n Output: {"result": {"event": "strikeout", "des": "Jeff Mathis strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 488721, "name": "peter bourjos"}}}? \n Output: {"result": {"event": "field_out", "des": "Peter Bourjos grounds out, shortstop Alcides Escobar to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 456714, "name": "billy butler"}}}? \n Output: {"result": {"event": "field_out", "des": "Billy Butler grounds out, second baseman Howie Kendrick to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 451500, "name": "kila ka\'aihue"}}}? \n Output: {"result": {"event": "field_out", "des": "Kila Ka\'aihue lines out to center fielder Peter Bourjos."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 425796, "name": "jeff francoeur"}}}? \n Output: {"result": {"event": "field_out", "des": "Jeff Francoeur flies out to right fielder Torii Hunter."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430895, "name": "maicer izturis"}}}? \n Output: {"result": {"event": "field_out", "des": "Maicer Izturis grounds out softly, second baseman Chris Getz to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 435062, "name": "howie kendrick"}}}? \n Output: {"result": {"event": "strikeout", "des": "Howie Kendrick strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 110029, "name": "bobby abreu"}}}? \n Output: {"result": {"event": "field_out", "des": "Bobby Abreu grounds out softly, shortstop Alcides Escobar to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 444876, "name": "alcides escobar"}}}? \n Output: {"result": {"event": "field_out", "des": "Alcides Escobar flies out to center fielder Peter Bourjos."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 276354, "name": "matt treanor"}}}? \n Output: {"result": {"event": "field_out", "des": "Matt Treanor grounds out, third baseman Maicer Izturis to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 460051, "name": "chris getz"}}}? \n Output: {"result": {"event": "walk", "des": "Chris Getz walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "caught_stealing_2b", "des": "Chris Getz caught stealing 2nd base, catcher Jeff Mathis to second baseman Howie Kendrick."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 116338, "name": "torii hunter"}}}? \n Output: {"result": {"event": "home_run", "des": "Torii Hunter homers (1) on a fly ball to center field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 150484, "name": "vernon wells"}}}? \n Output: {"result": {"event": "double", "des": "Vernon Wells doubles (1) on a ground ball to left fielder Alex Gordon."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430947, "name": "erick aybar"}}}? \n Output: {"result": {"event": "double", "des": "Erick Aybar doubles (1) on a line drive to right fielder Jeff Francoeur.   Vernon Wells scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 444432, "name": "mark trumbo"}}}? \n Output: {"result": {"event": "field_out", "des": "Mark Trumbo lines out to second baseman Chris Getz."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 425772, "name": "jeff mathis"}}}? \n Output: {"result": {"event": "field_out", "des": "Jeff Mathis grounds out softly, third baseman Mike Aviles to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 488721, "name": "peter bourjos"}}}? \n Output: {"result": {"event": "field_out", "des": "Peter Bourjos flies out to center fielder Melky Cabrera."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "field_out", "des": "Mike Aviles grounds out, third baseman Maicer Izturis to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 466320, "name": "melky cabrera"}}}? \n Output: {"result": {"event": "single", "des": "Melky Cabrera singles on a soft line drive to left fielder Vernon Wells."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 460086, "name": "alex gordon"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alex Gordon strikes out swinging.  Melky Cabrera steals (1) 2nd base."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 456714, "name": "billy butler"}}}? \n Output: {"result": {"event": "walk", "des": "Billy Butler walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 451500, "name": "kila ka\'aihue"}}}? \n Output: {"result": {"event": "strikeout", "des": "Kila Ka\'aihue strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430895, "name": "maicer izturis"}}}? \n Output: {"result": {"event": "field_out", "des": "Maicer Izturis grounds out, second baseman Chris Getz to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 435062, "name": "howie kendrick"}}}? \n Output: {"result": {"event": "field_out", "des": "Howie Kendrick grounds out softly, third baseman Mike Aviles to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 110029, "name": "bobby abreu"}}}? \n Output: {"result": {"event": "single", "des": "Bobby Abreu singles on a line drive to right fielder Jeff Francoeur."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 116338, "name": "torii hunter"}}}? \n Output: {"result": {"event": "single", "des": "Torii Hunter singles on a soft line drive to center fielder Melky Cabrera.   Bobby Abreu to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 150484, "name": "vernon wells"}}}? \n Output: {"result": {"event": "field_out", "des": "Vernon Wells grounds out, third baseman Mike Aviles to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 425796, "name": "jeff francoeur"}}}? \n Output: {"result": {"event": "field_out", "des": "Jeff Francoeur flies out to center fielder Peter Bourjos."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 444876, "name": "alcides escobar"}}}? \n Output: {"result": {"event": "field_out", "des": "Alcides Escobar grounds out softly, third baseman Maicer Izturis to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 276354, "name": "matt treanor"}}}? \n Output: {"result": {"event": "strikeout", "des": "Matt Treanor strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430947, "name": "erick aybar"}}}? \n Output: {"result": {"event": "field_out", "des": "Erick Aybar grounds out softly, second baseman Chris Getz to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 444432, "name": "mark trumbo"}}}? \n Output: {"result": {"event": "strikeout", "des": "Mark Trumbo strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 425772, "name": "jeff mathis"}}}? \n Output: {"result": {"event": "home_run", "des": "Jeff Mathis homers (1) on a fly ball to left center field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 488721, "name": "peter bourjos"}}}? \n Output: {"result": {"event": "single", "des": "Peter Bourjos singles on a bunt ground ball to pitcher Luke Hochevar.  Peter Bourjos advances to 3rd, on a throwing error by pitcher Luke Hochevar.  Peter Bourjos advances to 3rd, on a throwing error by second baseman Chris Getz."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460024, "name": "luke hochevar"}, "batter": {"id": 430895, "name": "maicer izturis"}}}? \n Output: {"result": {"event": "single", "des": "Maicer Izturis singles on a line drive to center fielder Melky Cabrera.   Peter Bourjos scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543070, "name": "aaron crow"}, "batter": {"id": 435062, "name": "howie kendrick"}}}? \n Output: {"result": {"event": "strikeout", "des": "Howie Kendrick strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 460051, "name": "chris getz"}}}? \n Output: {"result": {"event": "strikeout", "des": "Chris Getz strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "field_out", "des": "Mike Aviles flies out to right fielder Torii Hunter."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 466320, "name": "melky cabrera"}}}? \n Output: {"result": {"event": "single", "des": "Melky Cabrera singles on a ground ball to center fielder Peter Bourjos."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 460086, "name": "alex gordon"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alex Gordon called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543070, "name": "aaron crow"}, "batter": {"id": 110029, "name": "bobby abreu"}}}? \n Output: {"result": {"event": "field_out", "des": "Bobby Abreu flies out to left fielder Alex Gordon."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543070, "name": "aaron crow"}, "batter": {"id": 116338, "name": "torii hunter"}}}? \n Output: {"result": {"event": "strikeout", "des": "Torii Hunter strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543070, "name": "aaron crow"}, "batter": {"id": 150484, "name": "vernon wells"}}}? \n Output: {"result": {"event": "strikeout", "des": "Vernon Wells strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450308, "name": "jered weaver"}, "batter": {"id": 456714, "name": "billy butler"}}}? \n Output: {"result": {"event": "field_out", "des": "Billy Butler pops out to second baseman Howie Kendrick."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 538227, "name": "hisanori takahashi"}, "batter": {"id": 451500, "name": "kila ka\'aihue"}}}? \n Output: {"result": {"event": "field_out", "des": "Kila Ka\'aihue grounds out softly, pitcher Hisanori Takahashi to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 538227, "name": "hisanori takahashi"}, "batter": {"id": 425796, "name": "jeff francoeur"}}}? \n Output: {"result": {"event": "home_run", "des": "Jeff Francoeur homers (1) on a fly ball to left field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 538227, "name": "hisanori takahashi"}, "batter": {"id": 444876, "name": "alcides escobar"}}}? \n Output: {"result": {"event": "single", "des": "Alcides Escobar singles on a ground ball to right fielder Torii Hunter."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 538227, "name": "hisanori takahashi"}, "batter": {"id": 276354, "name": "matt treanor"}}}? \n Output: {"result": {"event": "single", "des": "Matt Treanor singles on a ground ball to center fielder Peter Bourjos.   Alcides Escobar to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 477229, "name": "jordan walden"}, "batter": {"id": 400140, "name": "wilson betemit"}}}? \n Output: {"result": {"event": "strikeout", "des": "Wilson Betemit strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 502264, "name": "nathan adcock"}, "batter": {"id": 430947, "name": "erick aybar"}}}? \n Output: {"result": {"event": "field_out", "des": "Erick Aybar grounds out, second baseman Mike Aviles to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 502264, "name": "nathan adcock"}, "batter": {"id": 444432, "name": "mark trumbo"}}}? \n Output: {"result": {"event": "field_out", "des": "Mark Trumbo grounds out softly to first baseman Kila Ka\'aihue."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 502264, "name": "nathan adcock"}, "batter": {"id": 425772, "name": "jeff mathis"}}}? \n Output: {"result": {"event": "double", "des": "Jeff Mathis doubles (1) on a line drive to left fielder Alex Gordon."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 502264, "name": "nathan adcock"}, "batter": {"id": 488721, "name": "peter bourjos"}}}? \n Output: {"result": {"event": "single", "des": "Peter Bourjos singles on a line drive to right fielder Jeff Francoeur.  Jeff Mathis out at home on the throw, right fielder Jeff Francoeur to catcher Matt Treanor."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 448178, "name": "kevin jepsen"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "home_run", "des": "Mike Aviles homers (1) on a fly ball to left field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 448178, "name": "kevin jepsen"}, "batter": {"id": 466320, "name": "melky cabrera"}}}? \n Output: {"result": {"event": "walk", "des": "Melky Cabrera walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 448178, "name": "kevin jepsen"}, "batter": {"id": 460086, "name": "alex gordon"}}}? \n Output: {"result": {"event": "field_out", "des": "Alex Gordon grounds out, shortstop Erick Aybar to first baseman Mark Trumbo."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 448178, "name": "kevin jepsen"}, "batter": {"id": 456714, "name": "billy butler"}}}? \n Output: {"result": {"event": "walk", "des": "Billy Butler walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543409, "name": "michael kohn"}, "batter": {"id": 451500, "name": "kila ka\'aihue"}}}? \n Output: {"result": {"event": "walk", "des": "Kila Ka\'aihue walks.   Melky Cabrera to 3rd.    Mitch Maier to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543409, "name": "michael kohn"}, "batter": {"id": 425796, "name": "jeff francoeur"}}}? \n Output: {"result": {"event": "strikeout", "des": "Jeff Francoeur strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 543409, "name": "michael kohn"}, "batter": {"id": 444876, "name": "alcides escobar"}}}? \n Output: {"result": {"event": "field_out", "des": "Alcides Escobar flies out to right fielder Torii Hunter."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 525768, "name": "tim collins"}, "batter": {"id": 430895, "name": "maicer izturis"}}}? \n Output: {"result": {"event": "single", "des": "Maicer Izturis singles on a line drive to left fielder Melky Cabrera."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 525768, "name": "tim collins"}, "batter": {"id": 435062, "name": "howie kendrick"}}}? \n Output: {"result": {"event": "sac_bunt", "des": "Howie Kendrick out on a sacrifice bunt to first baseman Alex Gordon.   Maicer Izturis to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 525768, "name": "tim collins"}, "batter": {"id": 110029, "name": "bobby abreu"}}}? \n Output: {"result": {"event": "walk", "des": "Bobby Abreu walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 525768, "name": "tim collins"}, "batter": {"id": 116338, "name": "torii hunter"}}}? \n Output: {"result": {"event": "strikeout", "des": "Torii Hunter strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 525768, "name": "tim collins"}, "batter": {"id": 150484, "name": "vernon wells"}}}? \n Output: {"result": {"event": "field_out", "des": "Vernon Wells flies out to left fielder Melky Cabrera."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 407845, "name": "fernando rodney"}, "batter": {"id": 276354, "name": "matt treanor"}}}? \n Output: {"result": {"event": "walk", "des": "Matt Treanor walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 407845, "name": "fernando rodney"}, "batter": {"id": 400140, "name": "wilson betemit"}}}? \n Output: {"result": {"event": "strikeout", "des": "Wilson Betemit strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 407845, "name": "fernando rodney"}, "batter": {"id": 449107, "name": "mike aviles"}}}? \n Output: {"result": {"event": "field_out", "des": "Mike Aviles pops out to first baseman Mark Trumbo in foul territory."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 407845, "name": "fernando rodney"}, "batter": {"id": 466320, "name": "melky cabrera"}}}? \n Output: {"result": {"event": "single", "des": "Melky Cabrera singles on a line drive to right fielder Torii Hunter.   Matt Treanor to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 407845, "name": "fernando rodney"}, "batter": {"id": 460086, "name": "alex gordon"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alex Gordon strikes out on a foul tip."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 445988, "name": "martin prado"}}}? \n Output: {"result": {"event": "field_out", "des": "Martin Prado grounds out softly, pitcher Livan Hernandez to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 434661, "name": "nate mclouth"}}}? \n Output: {"result": {"event": "field_out", "des": "Nate McLouth flies out to left fielder Michael Morse."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 116706, "name": "chipper jones"}}}? \n Output: {"result": {"event": "double", "des": "Chipper Jones doubles (1) on a line drive to right fielder Jayson Werth."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 435263, "name": "brian mccann"}}}? \n Output: {"result": {"event": "single", "des": "Brian McCann singles on a ground ball to center fielder Rick Ankiel, deflected by right fielder Jayson Werth.   Chipper Jones scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 462564, "name": "dan uggla"}}}? \n Output: {"result": {"event": "field_out", "des": "Dan Uggla flies out to center fielder Rick Ankiel."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 435622, "name": "ian desmond"}}}? \n Output: {"result": {"event": "strikeout", "des": "Ian Desmond called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 150029, "name": "jayson werth"}}}? \n Output: {"result": {"event": "single", "des": "Jayson Werth singles on a ground ball to center fielder Nate McLouth."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 475582, "name": "ryan zimmerman"}}}? \n Output: {"result": {"event": "single", "des": "Ryan Zimmerman singles on a ground ball to right fielder Jason Heyward.   Jayson Werth to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 425560, "name": "adam laroche"}}}? \n Output: {"result": {"event": "field_out", "des": "Adam LaRoche pops out to second baseman Dan Uggla."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 434604, "name": "mike morse"}}}? \n Output: {"result": {"event": "field_out", "des": "Michael Morse grounds out, shortstop Alex Gonzalez to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 518792, "name": "jason heyward"}}}? \n Output: {"result": {"event": "home_run", "des": "Jason Heyward homers (1) on a line drive to right field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 136460, "name": "alex gonzalez"}}}? \n Output: {"result": {"event": "field_out", "des": "Alex Gonzalez flies out to left fielder Michael Morse."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 518692, "name": "freddie freeman"}}}? \n Output: {"result": {"event": "field_out", "des": "Freddie Freeman grounds out to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 117955, "name": "derek lowe"}}}? \n Output: {"result": {"event": "field_out", "des": "Derek Lowe grounds out softly, pitcher Livan Hernandez to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 150449, "name": "rick ankiel"}}}? \n Output: {"result": {"event": "field_out", "des": "Rick Ankiel flies out to right fielder Jason Heyward."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 457787, "name": "danny espinosa"}}}? \n Output: {"result": {"event": "single", "des": "Danny Espinosa singles on a soft ground ball to catcher Brian McCann."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 121358, "name": "ivan rodriguez"}}}? \n Output: {"result": {"event": "field_out", "des": "Ivan Rodriguez grounds out, third baseman Chipper Jones to first baseman Freddie Freeman.   Danny Espinosa to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 115817, "name": "livan hernandez"}}}? \n Output: {"result": {"event": "field_out", "des": "Livan Hernandez grounds out softly, pitcher Derek Lowe to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 445988, "name": "martin prado"}}}? \n Output: {"result": {"event": "field_out", "des": "Martin Prado flies out to right fielder Jayson Werth."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 434661, "name": "nate mclouth"}}}? \n Output: {"result": {"event": "strikeout", "des": "Nate McLouth called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 116706, "name": "chipper jones"}}}? \n Output: {"result": {"event": "field_out", "des": "Chipper Jones flies out to left fielder Michael Morse."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 435622, "name": "ian desmond"}}}? \n Output: {"result": {"event": "strikeout", "des": "Ian Desmond strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 150029, "name": "jayson werth"}}}? \n Output: {"result": {"event": "strikeout", "des": "Jayson Werth strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 475582, "name": "ryan zimmerman"}}}? \n Output: {"result": {"event": "strikeout", "des": "Ryan Zimmerman called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 435263, "name": "brian mccann"}}}? \n Output: {"result": {"event": "field_out", "des": "Brian McCann grounds out, first baseman Adam LaRoche to pitcher Livan Hernandez."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 462564, "name": "dan uggla"}}}? \n Output: {"result": {"event": "strikeout", "des": "Dan Uggla strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 518792, "name": "jason heyward"}}}? \n Output: {"result": {"event": "strikeout", "des": "Jason Heyward called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 425560, "name": "adam laroche"}}}? \n Output: {"result": {"event": "field_out", "des": "Adam LaRoche flies out to left fielder Martin Prado."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 434604, "name": "mike morse"}}}? \n Output: {"result": {"event": "strikeout", "des": "Michael Morse called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 150449, "name": "rick ankiel"}}}? \n Output: {"result": {"event": "walk", "des": "Rick Ankiel walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 457787, "name": "danny espinosa"}}}? \n Output: {"result": {"event": "caught_stealing_2b", "des": "Rick Ankiel caught stealing 2nd base, catcher Brian McCann to shortstop Alex Gonzalez."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 136460, "name": "alex gonzalez"}}}? \n Output: {"result": {"event": "field_out", "des": "Alex Gonzalez flies out softly to right fielder Jayson Werth."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 518692, "name": "freddie freeman"}}}? \n Output: {"result": {"event": "field_out", "des": "Freddie Freeman flies out to center fielder Rick Ankiel."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 117955, "name": "derek lowe"}}}? \n Output: {"result": {"event": "field_out", "des": "Derek Lowe grounds out, second baseman Danny Espinosa to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 457787, "name": "danny espinosa"}}}? \n Output: {"result": {"event": "field_out", "des": "Danny Espinosa grounds out softly, pitcher Derek Lowe to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 121358, "name": "ivan rodriguez"}}}? \n Output: {"result": {"event": "field_out", "des": "Ivan Rodriguez grounds out, second baseman Dan Uggla to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 115817, "name": "livan hernandez"}}}? \n Output: {"result": {"event": "strikeout", "des": "Livan Hernandez called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 445988, "name": "martin prado"}}}? \n Output: {"result": {"event": "field_out", "des": "Martin Prado lines out to right fielder Jayson Werth."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 434661, "name": "nate mclouth"}}}? \n Output: {"result": {"event": "field_out", "des": "Nate McLouth grounds out, second baseman Danny Espinosa to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 116706, "name": "chipper jones"}}}? \n Output: {"result": {"event": "field_out", "des": "Chipper Jones grounds out, third baseman Ryan Zimmerman to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 435622, "name": "ian desmond"}}}? \n Output: {"result": {"event": "field_out", "des": "Ian Desmond grounds out, third baseman Chipper Jones to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 150029, "name": "jayson werth"}}}? \n Output: {"result": {"event": "field_out", "des": "Jayson Werth grounds out, shortstop Alex Gonzalez to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 117955, "name": "derek lowe"}, "batter": {"id": 475582, "name": "ryan zimmerman"}}}? \n Output: {"result": {"event": "walk", "des": "Ryan Zimmerman walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 447714, "name": "eric o\'flaherty"}, "batter": {"id": 425560, "name": "adam laroche"}}}? \n Output: {"result": {"event": "single", "des": "Adam LaRoche singles on a soft line drive to left fielder Martin Prado.   Ryan Zimmerman to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 447714, "name": "eric o\'flaherty"}, "batter": {"id": 434604, "name": "mike morse"}}}? \n Output: {"result": {"event": "force_out", "des": "Michael Morse grounds into a force out, shortstop Alex Gonzalez to second baseman Dan Uggla.   Adam LaRoche out at 2nd.    Michael Morse to 1st."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 435263, "name": "brian mccann"}}}? \n Output: {"result": {"event": "single", "des": "Brian McCann singles on a sharp ground ball to center fielder Rick Ankiel, deflected by pitcher Livan Hernandez."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 115817, "name": "livan hernandez"}, "batter": {"id": 462564, "name": "dan uggla"}}}? \n Output: {"result": {"event": "force_out", "des": "Dan Uggla grounds into a force out, third baseman Ryan Zimmerman to second baseman Danny Espinosa.   Brian McCann out at 2nd.    Dan Uggla to 1st."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460657, "name": "doug slaten"}, "batter": {"id": 518792, "name": "jason heyward"}}}? \n Output: {"result": {"event": "walk", "des": "Jason Heyward walks.   Dan Uggla to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 461325, "name": "tyler clippard"}, "batter": {"id": 136460, "name": "alex gonzalez"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alex Gonzalez strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 461325, "name": "tyler clippard"}, "batter": {"id": 518692, "name": "freddie freeman"}}}? \n Output: {"result": {"event": "field_out", "des": "Freddie Freeman flies out to left fielder Michael Morse."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 447714, "name": "eric o\'flaherty"}, "batter": {"id": 150449, "name": "rick ankiel"}}}? \n Output: {"result": {"event": "field_out", "des": "Rick Ankiel flies out to left fielder Martin Prado."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 447714, "name": "eric o\'flaherty"}, "batter": {"id": 457787, "name": "danny espinosa"}}}? \n Output: {"result": {"event": "double", "des": "Danny Espinosa doubles (1) on a line drive to left fielder Martin Prado."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 447714, "name": "eric o\'flaherty"}, "batter": {"id": 121358, "name": "ivan rodriguez"}}}? \n Output: {"result": {"event": "field_out", "des": "Ivan Rodriguez grounds out, first baseman Freddie Freeman to pitcher Eric O\'Flaherty.   Danny Espinosa to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 493247, "name": "peter moylan"}, "batter": {"id": 425556, "name": "laynce nix"}}}? \n Output: {"result": {"event": "strikeout", "des": "Laynce Nix strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434298, "name": "todd coffey"}, "batter": {"id": 400134, "name": "eric hinske"}}}? \n Output: {"result": {"event": "field_out", "des": "Eric Hinske grounds out, shortstop Ian Desmond to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434298, "name": "todd coffey"}, "batter": {"id": 445988, "name": "martin prado"}}}? \n Output: {"result": {"event": "field_out", "des": "Martin Prado pops out to first baseman Adam LaRoche."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434298, "name": "todd coffey"}, "batter": {"id": 434661, "name": "nate mclouth"}}}? \n Output: {"result": {"event": "field_out", "des": "Nate McLouth flies out to left fielder Michael Morse."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458924, "name": "jonny venters"}, "batter": {"id": 435622, "name": "ian desmond"}}}? \n Output: {"result": {"event": "field_out", "des": "Ian Desmond grounds out, third baseman Chipper Jones to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458924, "name": "jonny venters"}, "batter": {"id": 150029, "name": "jayson werth"}}}? \n Output: {"result": {"event": "field_out", "des": "Jayson Werth grounds out, shortstop Alex Gonzalez to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458924, "name": "jonny venters"}, "batter": {"id": 475582, "name": "ryan zimmerman"}}}? \n Output: {"result": {"event": "field_out", "des": "Ryan Zimmerman grounds out, third baseman Chipper Jones to first baseman Freddie Freeman."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430634, "name": "sean burnett"}, "batter": {"id": 116706, "name": "chipper jones"}}}? \n Output: {"result": {"event": "single", "des": "Chipper Jones singles on a sharp ground ball to center fielder Rick Ankiel."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430634, "name": "sean burnett"}, "batter": {"id": 435263, "name": "brian mccann"}}}? \n Output: {"result": {"event": "grounded_into_double_play", "des": "Brian McCann grounds into a double play, pitcher Sean Burnett to shortstop Ian Desmond to first baseman Adam LaRoche.   Chipper Jones out at 2nd.    Brian McCann out at 1st."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430634, "name": "sean burnett"}, "batter": {"id": 462564, "name": "dan uggla"}}}? \n Output: {"result": {"event": "strikeout", "des": "Dan Uggla strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 518886, "name": "craig kimbrel"}, "batter": {"id": 425560, "name": "adam laroche"}}}? \n Output: {"result": {"event": "field_out", "des": "Adam LaRoche flies out to left fielder Martin Prado."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 518886, "name": "craig kimbrel"}, "batter": {"id": 434604, "name": "mike morse"}}}? \n Output: {"result": {"event": "strikeout", "des": "Michael Morse strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 518886, "name": "craig kimbrel"}, "batter": {"id": 150449, "name": "rick ankiel"}}}? \n Output: {"result": {"event": "strikeout", "des": "Rick Ankiel called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 457706, "name": "austin jackson"}}}? \n Output: {"result": {"event": "strikeout", "des": "Austin Jackson strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 489242, "name": "will rhymes"}}}? \n Output: {"result": {"event": "field_out", "des": "Will Rhymes lines out to center fielder Curtis Granderson."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 120044, "name": "magglio ordonez"}}}? \n Output: {"result": {"event": "field_out", "des": "Magglio Ordonez lines out sharply to center fielder Curtis Granderson."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 458731, "name": "brett gardner"}}}? \n Output: {"result": {"event": "strikeout", "des": "Brett Gardner strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 116539, "name": "derek jeter"}}}? \n Output: {"result": {"event": "field_out", "des": "Derek Jeter lines out softly to second baseman Will Rhymes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 407893, "name": "mark teixeira"}}}? \n Output: {"result": {"event": "walk", "des": "Mark Teixeira walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 121347, "name": "alex rodriguez"}}}? \n Output: {"result": {"event": "walk", "des": "Alex Rodriguez walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 429664, "name": "robinson cano"}}}? \n Output: {"result": {"event": "strikeout", "des": "Robinson Cano strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 408234, "name": "miguel cabrera"}}}? \n Output: {"result": {"event": "single", "des": "Miguel Cabrera singles on a line drive to left fielder Brett Gardner."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 400121, "name": "victor martinez"}}}? \n Output: {"result": {"event": "single", "des": "Victor Martinez singles on a sharp ground ball to center fielder Curtis Granderson, deflected by shortstop Derek Jeter.   Miguel Cabrera to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 430605, "name": "ryan raburn"}}}? \n Output: {"result": {"event": "walk", "des": "Ryan Raburn walks.   Miguel Cabrera to 3rd.    Victor Martinez to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 425509, "name": "jhonny peralta"}}}? \n Output: {"result": {"event": "sac_fly", "des": "Jhonny Peralta out on a sacrifice fly to center fielder Curtis Granderson.   Miguel Cabrera scores.    Victor Martinez to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 276346, "name": "brandon inge"}}}? \n Output: {"result": {"event": "field_out", "des": "Brandon Inge lines out to second baseman Robinson Cano."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 488671, "name": "alex avila"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alex Avila strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 430897, "name": "nick swisher"}}}? \n Output: {"result": {"event": "field_out", "des": "Nick Swisher flies out to left fielder Ryan Raburn."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 120691, "name": "jorge posada"}}}? \n Output: {"result": {"event": "field_out", "des": "Jorge Posada flies out to left fielder Ryan Raburn."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 434158, "name": "curtis granderson"}}}? \n Output: {"result": {"event": "strikeout", "des": "Curtis Granderson strikes out on a foul tip."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 457706, "name": "austin jackson"}}}? \n Output: {"result": {"event": "strikeout", "des": "Austin Jackson strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 489242, "name": "will rhymes"}}}? \n Output: {"result": {"event": "strikeout", "des": "Will Rhymes strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 120044, "name": "magglio ordonez"}}}? \n Output: {"result": {"event": "field_out", "des": "Magglio Ordonez grounds out, third baseman Alex Rodriguez to first baseman Mark Teixeira."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 431145, "name": "russell martin"}}}? \n Output: {"result": {"event": "single", "des": "Russell Martin singles on a sharp line drive to left fielder Ryan Raburn."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 458731, "name": "brett gardner"}}}? \n Output: {"result": {"event": "sac_bunt", "des": "Brett Gardner out on a sacrifice bunt, first baseman Miguel Cabrera to second baseman Will Rhymes.   Russell Martin to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 116539, "name": "derek jeter"}}}? \n Output: {"result": {"event": "walk", "des": "Derek Jeter walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 407893, "name": "mark teixeira"}}}? \n Output: {"result": {"event": "home_run", "des": "Mark Teixeira homers (1) on a fly ball to right field.    Russell Martin scores.    Derek Jeter scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 121347, "name": "alex rodriguez"}}}? \n Output: {"result": {"event": "field_out", "des": "Alex Rodriguez flies out to center fielder Austin Jackson."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 434378, "name": "justin verlander"}, "batter": {"id": 429664, "name": "robinson cano"}}}? \n Output: {"result": {"event": "strikeout", "des": "Robinson Cano strikes out on a foul tip."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 282332, "name": "cc sabathia"}, "batter": {"id": 408234, "name": "miguel cabrera"}}}? \n Output: {"result": {"event": "walk", "des": "Miguel Cabrera walks."}}\n',
# ...
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 407487, "name": "juan rivera"}}}? \n Output: {"result": {"event": "strikeout", "des": "Juan Rivera strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 408047, "name": "justin morneau"}}}? \n Output: {"result": {"event": "field_out", "des": "Justin Morneau lines out to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430321, "name": "delmon young"}}}? \n Output: {"result": {"event": "strikeout", "des": "Delmon Young called out on strikes."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 150212, "name": "michael cuddyer"}}}? \n Output: {"result": {"event": "single", "des": "Michael Cuddyer singles on a ground ball to left fielder Travis Snider."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430585, "name": "jason kubel"}}}? \n Output: {"result": {"event": "strikeout", "des": "Jason Kubel strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 450317, "name": "j. p. arencibia"}}}? \n Output: {"result": {"event": "field_out", "des": "J.P. Arencibia flies out to right fielder Michael Cuddyer."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 434658, "name": "rajai davis"}}}? \n Output: {"result": {"event": "field_out", "des": "Rajai Davis grounds out, pitcher Carl Pavano to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 488862, "name": "yunel escobar"}}}? \n Output: {"result": {"event": "field_out", "des": "Yunel Escobar grounds out, third baseman Danny Valencia to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 502143, "name": "danny valencia"}}}? \n Output: {"result": {"event": "field_out", "des": "Danny Valencia grounds out, third baseman Edwin Encarnacion to first baseman Adam Lind."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 458210, "name": "alexi casilla"}}}? \n Output: {"result": {"event": "field_out", "des": "Alexi Casilla flies out to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 452655, "name": "denard span"}}}? \n Output: {"result": {"event": "single", "des": "Denard Span singles on a ground ball to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 457292, "name": "tsuyoshi nishioka"}}}? \n Output: {"result": {"event": "strikeout", "des": "Tsuyoshi Nishioka strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 430832, "name": "jose bautista"}}}? \n Output: {"result": {"event": "field_out", "des": "Jose Bautista grounds out, shortstop Alexi Casilla to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 452252, "name": "adam lind"}}}? \n Output: {"result": {"event": "field_out", "des": "Adam Lind pops out to shortstop Alexi Casilla in foul territory."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 431094, "name": "aaron hill"}}}? \n Output: {"result": {"event": "double", "des": "Aaron Hill doubles (1) on a line drive to left fielder Delmon Young."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 429665, "name": "edwin encarnacion"}}}? \n Output: {"result": {"event": "field_out", "des": "Edwin Encarnacion flies out to left fielder Delmon Young."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 408045, "name": "joe mauer"}}}? \n Output: {"result": {"event": "field_out", "des": "Joe Mauer flies out to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 408047, "name": "justin morneau"}}}? \n Output: {"result": {"event": "field_out", "des": "Justin Morneau flies out to right fielder Jose Bautista."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430321, "name": "delmon young"}}}? \n Output: {"result": {"event": "field_out", "des": "Delmon Young grounds out, second baseman Aaron Hill to first baseman Adam Lind."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 501983, "name": "travis snider"}}}? \n Output: {"result": {"event": "walk", "des": "Travis Snider walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 407487, "name": "juan rivera"}}}? \n Output: {"result": {"event": "field_out", "des": "Juan Rivera lines out to left fielder Delmon Young."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 450317, "name": "j. p. arencibia"}}}? \n Output: {"result": {"event": "home_run", "des": "J.P. Arencibia homers (1) on a fly ball to center field.   Travis Snider scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 434658, "name": "rajai davis"}}}? \n Output: {"result": {"event": "strikeout", "des": "Rajai Davis strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 488862, "name": "yunel escobar"}}}? \n Output: {"result": {"event": "strikeout", "des": "Yunel Escobar strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 150212, "name": "michael cuddyer"}}}? \n Output: {"result": {"event": "strikeout", "des": "Michael Cuddyer strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430585, "name": "jason kubel"}}}? \n Output: {"result": {"event": "field_out", "des": "Jason Kubel pops out to second baseman Aaron Hill."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 502143, "name": "danny valencia"}}}? \n Output: {"result": {"event": "field_out", "des": "Danny Valencia lines out to left fielder Travis Snider."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 430832, "name": "jose bautista"}}}? \n Output: {"result": {"event": "home_run", "des": "Jose Bautista homers (1) on a fly ball to left center field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 134321, "name": "carl pavano"}, "batter": {"id": 452252, "name": "adam lind"}}}? \n Output: {"result": {"event": "home_run", "des": "Adam Lind homers (1) on a fly ball to right field."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 431094, "name": "aaron hill"}}}? \n Output: {"result": {"event": "field_out", "des": "Aaron Hill grounds out, shortstop Alexi Casilla to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 429665, "name": "edwin encarnacion"}}}? \n Output: {"result": {"event": "field_out", "des": "Edwin Encarnacion pops out to shortstop Alexi Casilla."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 501983, "name": "travis snider"}}}? \n Output: {"result": {"event": "walk", "des": "Travis Snider walks."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 407487, "name": "juan rivera"}}}? \n Output: {"result": {"event": "walk", "des": "Juan Rivera walks.   Travis Snider to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 450317, "name": "j. p. arencibia"}}}? \n Output: {"result": {"event": "triple", "des": "J.P. Arencibia triples (1) on a fly ball to center fielder Denard Span.   Travis Snider scores.    Juan Rivera scores."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 453249, "name": "jeff manship"}, "batter": {"id": 434658, "name": "rajai davis"}}}? \n Output: {"result": {"event": "strikeout", "des": "Rajai Davis strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 458210, "name": "alexi casilla"}}}? \n Output: {"result": {"event": "strikeout", "des": "Alexi Casilla strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 452655, "name": "denard span"}}}? \n Output: {"result": {"event": "single", "des": "Denard Span singles on a ground ball to shortstop Yunel Escobar."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 457292, "name": "tsuyoshi nishioka"}}}? \n Output: {"result": {"event": "single", "des": "Tsuyoshi Nishioka singles on a ground ball to left fielder Travis Snider.   Denard Span to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 408045, "name": "joe mauer"}}}? \n Output: {"result": {"event": "strikeout", "des": "Joe Mauer strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 408047, "name": "justin morneau"}}}? \n Output: {"result": {"event": "field_out", "des": "Justin Morneau grounds out, first baseman Adam Lind to pitcher Ricky Romero."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450282, "name": "glen perkins"}, "batter": {"id": 488862, "name": "yunel escobar"}}}? \n Output: {"result": {"event": "field_out", "des": "Yunel Escobar grounds out, shortstop Alexi Casilla to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450282, "name": "glen perkins"}, "batter": {"id": 430832, "name": "jose bautista"}}}? \n Output: {"result": {"event": "single", "des": "Jose Bautista singles on a soft line drive to right fielder Michael Cuddyer."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 450282, "name": "glen perkins"}, "batter": {"id": 452252, "name": "adam lind"}}}? \n Output: {"result": {"event": "grounded_into_double_play", "des": "Adam Lind grounds into a double play, shortstop Alexi Casilla to second baseman Tsuyoshi Nishioka to first baseman Justin Morneau.   Jose Bautista out at 2nd.    Adam Lind out at 1st."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430321, "name": "delmon young"}}}? \n Output: {"result": {"event": "single", "des": "Delmon Young singles on a ground ball to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 150212, "name": "michael cuddyer"}}}? \n Output: {"result": {"event": "strikeout", "des": "Michael Cuddyer strikes out on a foul tip."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 430585, "name": "jason kubel"}}}? \n Output: {"result": {"event": "single", "des": "Jason Kubel singles on a line drive to right fielder Jose Bautista.   Delmon Young to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 502143, "name": "danny valencia"}}}? \n Output: {"result": {"event": "field_error", "des": "Danny Valencia reaches on a fielding error by third baseman Edwin Encarnacion.   Delmon Young scores.    Jason Kubel to 2nd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 460069, "name": "ricky romero"}, "batter": {"id": 458210, "name": "alexi casilla"}}}? \n Output: {"result": {"event": "double", "des": "Alexi Casilla doubles (1) on a ground ball to left fielder Travis Snider.   Jason Kubel scores.    Danny Valencia to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 445163, "name": "casey janssen"}, "batter": {"id": 452655, "name": "denard span"}}}? \n Output: {"result": {"event": "field_out", "des": "Denard Span grounds out, first baseman Adam Lind to pitcher Casey Janssen.   Danny Valencia scores.    Alexi Casilla to 3rd."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 445163, "name": "casey janssen"}, "batter": {"id": 457292, "name": "tsuyoshi nishioka"}}}? \n Output: {"result": {"event": "field_out", "des": "Tsuyoshi Nishioka grounds out, pitcher Casey Janssen to first baseman Adam Lind."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458713, "name": "kevin slowey"}, "batter": {"id": 431094, "name": "aaron hill"}}}? \n Output: {"result": {"event": "strikeout", "des": "Aaron Hill strikes out swinging."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458713, "name": "kevin slowey"}, "batter": {"id": 429665, "name": "edwin encarnacion"}}}? \n Output: {"result": {"event": "single", "des": "Edwin Encarnacion singles on a line drive to center fielder Denard Span."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458713, "name": "kevin slowey"}, "batter": {"id": 501983, "name": "travis snider"}}}? \n Output: {"result": {"event": "field_out", "des": "Travis Snider flies out to right fielder Michael Cuddyer."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 458713, "name": "kevin slowey"}, "batter": {"id": 407487, "name": "juan rivera"}}}? \n Output: {"result": {"event": "field_out", "des": "Juan Rivera grounds out, second baseman Tsuyoshi Nishioka to first baseman Justin Morneau."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430630, "name": "jason frasor"}, "batter": {"id": 408045, "name": "joe mauer"}}}? \n Output: {"result": {"event": "single", "des": "Joe Mauer singles on a line drive to center fielder Rajai Davis."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430630, "name": "jason frasor"}, "batter": {"id": 408047, "name": "justin morneau"}}}? \n Output: {"result": {"event": "grounded_into_double_play", "des": "Justin Morneau grounds into a double play, second baseman John McDonald to shortstop Yunel Escobar to first baseman Adam Lind.   Joe Mauer out at 2nd.    Justin Morneau out at 1st."}}\n',
#  'Instruct: what is the outcome of {"input": {"pitcher": {"id": 430630, "name": "jason frasor"}, "batter": {"id": 430321, "name": "delmon young"}}}? \n Output: {"result": {"event": "field_out", "des": "Delmon Young flies out to center fielder Rajai Davis."}}\n',
#  ...]

# %%
def get_training_corpus():
    return (
        raw_datasets["train"][i : i + 1000]
        for i in range(0, len(raw_datasets["train"]), 1000)
    )


training_corpus = get_training_corpus()

# %%
old_tokenizer = AutoTokenizer.from_pretrained("../models/phi-2", trust_remote_code=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
tokenizer = old_tokenizer.train_new_from_iterator(training_corpus, 55000)

# %%
example = "{\"pitcher\": {\"id\": 460024, \"name\": \"luke hochevar\"}, \"batter\": {\"id\": 488721, \"name\": \"peter bourjos\"}, \"p_throws\": \"R\", \"stand\": \"R\", \"inning_topbot\": \"Top\", \"inning\": 2, \"outs_when_up\": 2, \"on_1b\": \"\", \"on_2b\": \"\", \"on_3b\": \"\", \"home_score\": 0, \"away_score\": 0}"
tokens = tokenizer.tokenize(example)
old_tokens = old_tokenizer.tokenize(example)
print(len(tokens))
print(tokens)
print(old_tokens)
# Out:
# ['{', '"', 'p', 'i', 't', 'c', 'h', 'e', 'r', '"', ':', 'Ġ', '{', '"', 'i', 'd', '"', ':', 'Ġ', '4', '6', '0', '0', '2', '4', ',', 'Ġ', '"', 'n', 'a', 'm', 'e', '"', ':', 'Ġ', '"', 'l', 'u', 'k', 'e', 'Ġ', 'h', 'o', 'c', 'h', 'e', 'v', 'a', 'r', '"', '}', ',', 'Ġ', '"', 'b', 'a', 't', 't', 'e', 'r', '"', ':', 'Ġ', '{', '"', 'i', 'd', '"', ':', 'Ġ', '4', '8', '8', '7', '2', '1', ',', 'Ġ', '"', 'n', 'a', 'm', 'e', '"', ':', 'Ġ', '"', 'p', 'e', 't', 'e', 'r', 'Ġ', 'b', 'o', 'u', 'r', 'j', 'o', 's', '"', '}', ',', 'Ġ', '"', 'p', '_', 't', 'h', 'r', 'o', 'w', 's', '"', ':', 'Ġ', '"', 'R', '"', ',', 'Ġ', '"', 's', 't', 'a', 'n', 'd', '"', ':', 'Ġ', '"', 'R', '"', ',', 'Ġ', '"', 'i', 'n', 'n', 'i', 'n', 'g', '_', 't', 'o', 'p', 'b', 'o', 't', '"', ':', 'Ġ', '"', 'T', 'o', 'p', '"', ',', 'Ġ', '"', 'i', 'n', 'n', 'i', 'n', 'g', '"', ':', 'Ġ', '2', ',', 'Ġ', '"', 'o', 'u', 't', 's', '_', 'w', 'h', 'e', 'n', '_', 'u', 'p', '"', ':', 'Ġ', '2', ',', 'Ġ', '"', 'o', 'n', '_', '1', 'b', '"', ':', 'Ġ', '"', '"', ',', 'Ġ', '"', 'o', 'n', '_', '2', 'b', '"', ':', 'Ġ', '"', '"', ',', 'Ġ', '"', 'o', 'n', '_', '3', 'b', '"', ':', 'Ġ', '"', '"', ',', 'Ġ', '"', 'h', 'o', 'm', 'e', '_', 's', 'c', 'o', 'r', 'e', '"', ':', 'Ġ', '0', ',', 'Ġ', '"', 'a', 'w', 'a', 'y', '_', 's', 'c', 'o', 'r', 'e', '"', ':', 'Ġ', '0', '}']
# ['{"', 'pit', 'cher', '":', 'Ġ{"', 'id', '":', 'Ġ46', '00', '24', ',', 'Ġ"', 'name', '":', 'Ġ"', 'lu', 'ke', 'Ġh', 'oche', 'var', '"},', 'Ġ"', 'b', 'atter', '":', 'Ġ{"', 'id', '":', 'Ġ4', '887', '21', ',', 'Ġ"', 'name', '":', 'Ġ"', 'p', 'eter', 'Ġbour', 'j', 'os', '"},', 'Ġ"', 'p', '_', 'th', 'rows', '":', 'Ġ"', 'R', '",', 'Ġ"', 'stand', '":', 'Ġ"', 'R', '",', 'Ġ"', 'inning', '_', 'top', 'bot', '":', 'Ġ"', 'Top', '",', 'Ġ"', 'inning', '":', 'Ġ2', ',', 'Ġ"', 'outs', '_', 'when', '_', 'up', '":', 'Ġ2', ',', 'Ġ"', 'on', '_', '1', 'b', '":', 'Ġ"', '",', 'Ġ"', 'on', '_', '2', 'b', '":', 'Ġ"', '",', 'Ġ"', 'on', '_', '3', 'b', '":', 'Ġ"', '",', 'Ġ"', 'home', '_', 'score', '":', 'Ġ0', ',', 'Ġ"', 'away', '_', 'score', '":', 'Ġ0', '}']

# %%
tokenizer.save_pretrained("../models/phi-2-mlb/tokenizer/")
