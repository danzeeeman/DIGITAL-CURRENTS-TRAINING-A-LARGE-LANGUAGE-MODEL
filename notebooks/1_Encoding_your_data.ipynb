# %%
# %pip install unidecode
# %pip install pybaseball
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ---------------------------------------- 0.0/235.5 kB ? eta -:--:--
#    ----- ---------------------------------- 30.7/235.5 kB 1.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 30.7/235.5 kB 1.3 MB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/235.5 kB 544.7 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/235.5 kB 819.2 kB/s eta 0:00:01
#    ------------------- ------------------ 122.9/235.5 kB 722.1 kB/s eta 0:00:01
#    -------------------------------------- - 225.3/235.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 235.5/235.5 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8
# Note: you may need to restart the kernel to use updated packages.
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (2.2.0)
# Collecting beautifulsoup4>=4.4.0 (from pybaseball)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests>=2.18.1 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (2.31.0)
# Collecting lxml>=4.2.1 (from pybaseball)
#   Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: pyarrow>=1.0.1 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (15.0.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.2.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: scipy>=1.4.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (1.12.0)
# Collecting matplotlib>=2.0.0 (from pybaseball)
#   Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: tqdm>=4.50.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (4.66.1)
# Requirement already satisfied: attrs>=20.3.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pybaseball) (23.2.0)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.4.0->pybaseball)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0.0->pybaseball)
#   Downloading contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->pybaseball)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0.0->pybaseball)
#   Downloading fonttools-4.48.1-cp310-cp310-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.2 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/162.2 kB 1.3 MB/s eta 0:00:01
#      ------- ------------------------------- 30.7/162.2 kB 1.3 MB/s eta 0:00:01
#      -------------- ---------------------- 61.4/162.2 kB 656.4 kB/s eta 0:00:01
#      ------------------------- ---------- 112.6/162.2 kB 930.9 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/162.2 kB 717.5 kB/s eta 0:00:01
#      ------------------------------------ 162.2/162.2 kB 808.2 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0.0->pybaseball)
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (23.2)
# Requirement already satisfied: pillow>=8 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.0.0->pybaseball)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pandas>=1.0.3->pybaseball) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pandas>=1.0.3->pybaseball) (2023.4)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#      ---------------------------------------- 0.0/212.1 kB ? eta -:--:--
#      -------------------- ----------------- 112.6/212.1 kB 6.4 MB/s eta 0:00:01
#      -------------------- ----------------- 112.6/212.1 kB 6.4 MB/s eta 0:00:01
#      ------------------------------------ - 204.8/212.1 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 212.1/212.1 kB 1.8 MB/s eta 0:00:00
# Collecting pyjwt>=2.4.0 (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pygithub>=1.51->pybaseball) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from pygithub>=1.51->pybaseball) (2.2.0)
# Collecting Deprecated (from pygithub>=1.51->pybaseball)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from requests>=2.18.1->pybaseball) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from requests>=2.18.1->pybaseball) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from requests>=2.18.1->pybaseball) (2024.2.2)
# Requirement already satisfied: colorama in e:\src\transformer-sketchbook\.venv\lib\site-packages (from tqdm>=4.50.0->pybaseball) (0.4.6)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Downloading cryptography-42.0.2-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting cffi>=1.4.1 (from pynacl>=1.4.0->pygithub>=1.51->pybaseball)
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in e:\src\transformer-sketchbook\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.16.0)
# Collecting wrapt<2,>=1.10 (from Deprecated->pygithub>=1.51->pybaseball)
#   Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting pycparser (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ---------------------------------------- 0.0/426.1 kB ? eta -:--:--
#    --------------------- ------------------ 225.3/426.1 kB 6.9 MB/s eta 0:00:01
#    ------------------------ --------------- 256.0/426.1 kB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  419.8/426.1 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 426.1/426.1 kB 3.3 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 9.2 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 15.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.6/3.9 MB 18.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/3.9 MB 9.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.7/3.9 MB 13.6 MB/s eta 0:00:01
#    -------------------- ------------------- 2.0/3.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 3.3/3.9 MB 16.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.9 MB 17.0 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.9 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 10.8 MB/s eta 0:00:00
# Downloading matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ------- -------------------------------- 1.4/7.6 MB 30.5 MB/s eta 0:00:01
#    --------------- ------------------------ 2.9/7.6 MB 36.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.0/7.6 MB 36.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.6 MB 33.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.6 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 34.8 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 34.8 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 34.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 25.7 MB/s eta 0:00:00
# Downloading PyGithub-2.2.0-py3-none-any.whl (350 kB)
#    ---------------------------------------- 0.0/350.2 kB ? eta -:--:--
#    --------------------------------------- 350.2/350.2 kB 22.7 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
#    ---------------------------------------- 0.0/186.7 kB ? eta -:--:--
#    --------------------------------------- 186.7/186.7 kB 11.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.48.1-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------- -------------- 1.4/2.2 MB 45.3 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 23.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB ? eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    --------------------------------------- 181.6/181.6 kB 10.7 MB/s eta 0:00:00
# Downloading cryptography-42.0.2-cp39-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.5/2.9 MB 47.0 MB/s eta 0:00:01
#    ---------------------------------------  2.9/2.9 MB 45.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 26.1 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Installing collected packages: wrapt, soupsieve, pyparsing, pyjwt, pycparser, lxml, kiwisolver, fonttools, cycler, contourpy, matplotlib, Deprecated, cffi, beautifulsoup4, pynacl, cryptography, pygithub, pybaseball
# Successfully installed Deprecated-1.2.14 beautifulsoup4-4.12.3 cffi-1.16.0 contourpy-1.2.0 cryptography-42.0.2 cycler-0.12.1 fonttools-4.48.1 kiwisolver-1.4.5 lxml-5.1.0 matplotlib-3.8.2 pybaseball-2.2.7 pycparser-2.21 pygithub-2.2.0 pyjwt-2.8.0 pynacl-1.5.0 pyparsing-3.1.1 soupsieve-2.5 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
from pybaseball import statcast
from pybaseball import playerid_reverse_lookup
from unidecode import unidecode 
import os
import json
import time
import pickle
import random

# %% [markdown]
# ## Encoding a dataset for the [Alpaca LoRA](https://github.com/tloen/alpaca-lora) format.
#
# ### What's a [LoRA](https://github.com/microsoft/LoRA)?
#
# [Paper](https://www.microsoft.com/en-us/research/publication/lora-low-rank-adaptation-of-large-language-models/)
#
# A LoRA stands for Low-Rank Adaptation of Large Language Models.  LoRA reduces the number of trainable parameters by learning pairs of rank-decompostion matrices while freezing the original weights. This vastly reduces the storage requirement for large language models adapted to specific tasks and enables efficient task-switching during deployment all without introducing inference latency. LoRA also outperforms several other adaptation methods including adapter, prefix-tuning, and fine-tuning.
#
# ### [Stanford Alpaca](https://github.com/tatsu-lab/stanford_alpaca)
# Standfor Alpaca is an instruction-following LLaMA Model.
#
# ### [LLaMA](https://github.com/facebookresearch/llama)
#
# Meta developed and released the Llama 2 family of large language models (LLMs), a collection of pretrained and fine-tuned generative text models ranging in scale from 7 billion to 70 billion parameters. Our fine-tuned LLMs, called Llama-2-Chat, are optimized for dialogue use cases. Llama-2-Chat models outperform open-source chat models on most benchmarks we tested, and in our human evaluations for helpfulness and safety, are on par with some popular closed-source models like ChatGPT and PaLM.
#
# **Model Architecture** Llama 2 is an auto-regressive language model that uses an optimized transformer architecture. The tuned versions use supervised fine-tuning (SFT) and reinforcement learning with human feedback (RLHF) to align with human preferences for helpfulness and safety.
#
# **Research Paper** More information can be found in the paper "Llama-2: Open Foundation and Fine-tuned Chat Models", available at https://ai.meta.com/research/publications/llama-2-open-foundation-and-fine-tuned-chat-models/.
#
# **Where to send questions or comments about the model** Instructions on how to provide feedback or comments on the model can be found in the model [README](README.md).
#
# ## **Intended Use**
# **Intended Use Cases** Llama 2 is intended for commercial and research use in English. Tuned models are intended for assistant-like chat, whereas pretrained models can be adapted for a variety of natural language generation tasks.
#
# **Out-of-scope** Uses Use in any manner that violates applicable laws or regulations (including trade compliance laws). Use in any other way that is prohibited by the Acceptable Use Policy and Llama 2 Community License. Use in languages other than English**.
#
# **Note: Developers may fine-tune Llama 2 models for languages beyond English provided they comply with the Llama 2 Community License and the Acceptable Use Policy.
#
# ||Time (GPU hours)|Power Consumption (W)|Carbon Emitted(tCO<sub>2</sub>eq)|
# |---|---|---|---|
# |Llama 2 7B|184320|400|31.22|
# |Llama 2 13B|368640|400|62.44|
# |Llama 2 70B|1720320|400|291.42|
# |Total|3311616||539.00|
#
# ## **Training Data**
# **Overview** Llama 2 was pretrained on 2 trillion tokens of data from publicly available sources. The fine-tuning data includes publicly available instruction datasets, as well as over one million new human-annotated examples. Neither the pretraining nor the fine-tuning datasets include Meta user data.
#
# **Data Freshness** The pretraining data has a cutoff of September 2022, but some tuning data is more recent, up to July 2023.
#
# ## **Prompt Template**
#
# ```
# {
#     "description": "Template used by Alpaca-LoRA.",
#     "prompt_input": "Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\n{instruction}\n\n### Input:\n{input}\n\n### Response:\n",
#     "prompt_no_input": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n{instruction}\n\n### Response:\n",
#     "response_split": "### Response:"
# }
# ```
#
# ```"Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\n{instruction}\n\n### Input:\n{input}\n\n### Response:\n"```

# %%
path = "../data/seasons/"
files = os.listdir(path)
files.sort()
prompts = []
json_data = []
season_count = 0
for file in files:
    print(file)
    pickle_in = open(f"{path}/{file}","rb")
    every_pitch = pickle.load(pickle_in)
    every_pitch = every_pitch.iloc[::-1]
    for index, row in every_pitch.iterrows():
        if isinstance(row.events, str):
            instruction = f"what is the outcome of pitcher {row.pitcher} pitching to batter {row.batter}\n\n"
            input = f"{row.inning_topbot} of the {row.inning} inning with {row.outs_when_up} outs\n\n"
            pitch = f" a {f'{int(row.release_speed)} miles per hour ' if isinstance(row.release_speed, float) else ''}{row.pitch_name}"
            response = f"With {row.strikes} strike and {row.balls} balls, {row.pitcher} throws{pitch if isinstance(row.release_speed, float) else ''} to {row.batter}. {row.des}"
            prompts.append(f"Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n ### Instruction:\n{instruction} ### Input:\n{input} ### Response:\n{response}\n")
            json_data.append({
                "instruction":instruction,
                "input":input,
                "output":response
            })

with open(f'2011_2023_alpaca_text_encoded.json', 'w', encoding='utf-8') as f:
    json.dump(prompts, f, ensure_ascii=True, indent=4, allow_nan=True)
    f.close()

with open(f'2011_2023_alpaca_json.json', 'w', encoding='utf-8') as f:
    json.dump(json_data, f, ensure_ascii=True, indent=4, allow_nan=True)
    f.close()
# Out:
# season-2011.pickle
# season-2012.pickle
# season-2014.pickle
# season-2015.pickle
# season-2016.pickle
# season-2018.pickle
# season-2019.pickle
# season-2020.pickle
# season-2021.pickle
# season-2022.pickle
# season-2023.pickle
